# %% [markdown]
# <a href="https://colab.research.google.com/github/igarashimassaki/TurmaMECANICA1/blob/main/Aula10set24_PROD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exemplo 03) Programa para Verificar se PAR ou IMPAR

# %%
numero = int(input("Digite numero inteiro: "))
if numero % 2 == 0:
  print(f"O numero {numero} é PAR")
else:
  print(f"O numero {numero} é ÍMPAR")
# Out:
# Digite numero inteiro: 99
# O numero 99 é ÍMPAR
